# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import locale
locale.setlocale(locale.LC_TIME, 'Spanish_Spain.1252')
# Out:
# 'Spanish_Spain.1252'

# %% [markdown]
# # ETL - EDA

# %%
hechos = pd.read_excel('Archivos Origen/homicidios.xlsx', sheet_name='HECHOS')
hechos
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 0    2016-0001           1 2016-01-01  2016   1   1  04:00:00   4
# 1    2016-0002           1 2016-01-02  2016   1   2  01:15:00   1
# 2    2016-0003           1 2016-01-03  2016   1   3  07:00:00   7
# 3    2016-0004           1 2016-01-10  2016   1  10  00:00:00   0
# 4    2016-0005           1 2016-01-21  2016   1  21  05:20:00   5
# ..         ...         ...        ...   ...  ..  ..       ...  ..
# 691  2021-0093           1 2021-12-13  2021  12  13  17:10:00  17
# 692  2021-0094           1 2021-12-20  2021  12  20  01:10:00   1
# 693  2021-0095           1 2021-12-30  2021  12  30  00:43:00   0
# 694  2021-0096           1 2021-12-15  2021  12  15  10:30:00  10
# 695  2021-0097           1 2021-11-18  2021  11  18  06:10:00   6
#
#                                LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0    AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1            AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                           AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3        AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4    AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
# ..                                         ...           ...  ...     ...
# 691                          AV. RIESTRA Y MOM       AVENIDA  ...     NaN
# 692                    AU DELLEPIANE Y LACARRA     AUTOPISTA  ...     NaN
# 693                        AV. GAONA Y TERRADA       AVENIDA  ...     NaN
# 694                         AV. EVA PERON 4071       AVENIDA  ...  4071.0
# 695                    PADRE CARLOS MUJICA 709         CALLE  ...   709.0
#
#                                    Cruce  \
# 0    FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                    DE LOS CORRALES AV.
# 2                                    NaN
# 3               VILLEGAS, CONRADO, GRAL.
# 4                SAENZ PE?A, LUIS, PRES.
# ..                                   ...
# 691                                  MOM
# 692                          LACARRA AV.
# 693                              TERRADA
# 694                                  NaN
# 695                                  NaN
#
#                                  Dirección Normalizada COMUNA  \
# 0    PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...      8
# 1                 PAZ, GRAL. AV. y DE LOS CORRALES AV.      9
# 2                                  ENTRE RIOS AV. 2034      1
# 3            LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.      8
# 4              SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.      1
# ..                                                 ...    ...
# 691                                  RIESTRA AV. y MOM      7
# 692         DELLEPIANE, LUIS, TTE. GRAL. y LACARRA AV.      9
# 693                                GAONA AV. y TERRADA     11
# 694                                PERON, EVA AV. 4071      9
# 695                            PADRE CARLOS MUGICA 709      1
#
#                                    XY (CABA)         pos x         pos y  \
# 0      Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1      Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2     Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3      Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4    Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
# ..                                       ...           ...           ...
# 691   Point (102728.60090138 98186.24929177)  -58.43353773  -34.64561636
# 692    Point (99624.29795829 97569.69801131)  -58.46739825  -34.65117757
# 693   Point (99116.45492358 101045.23284826)  -58.47293407  -34.61984745
# 694    Point (99324.54463985 97676.26932409)  -58.47066794  -34.65021673
# 695  Point (107664.16647795 104708.63962087)  -58.37976155  -34.58679619
#
#       PARTICIPANTES    VICTIMA    ACUSADO
# 0         MOTO-AUTO       MOTO       AUTO
# 1    AUTO-PASAJEROS       AUTO  PASAJEROS
# 2         MOTO-AUTO       MOTO       AUTO
# 3           MOTO-SD       MOTO         SD
# 4    MOTO-PASAJEROS       MOTO  PASAJEROS
# ..              ...        ...        ...
# 691       MOTO-AUTO       MOTO       AUTO
# 692       MOTO-AUTO       MOTO       AUTO
# 693     MOTO-CARGAS       MOTO     CARGAS
# 694     AUTO-CARGAS       AUTO     CARGAS
# 695  BICICLETA-AUTO  BICICLETA       AUTO
#
# [696 rows x 21 columns]

# %%
hechos.columns
# Out:
# Index(['ID', 'N_VICTIMAS', 'FECHA', 'AAAA', 'MM', 'DD', 'HORA', 'HH',
#        'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'Calle', 'Altura', 'Cruce',
#        'Dirección Normalizada', 'COMUNA', 'XY (CABA)', 'pos x', 'pos y',
#        'PARTICIPANTES', 'VICTIMA', 'ACUSADO'],
#       dtype='object')

# %%
hechos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    datetime64[ns]
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   696 non-null    object
#  7   HH                     696 non-null    object
#  8   LUGAR_DEL_HECHO        696 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  Calle                  695 non-null    object
#  11  Altura                 129 non-null    float64
#  12  Cruce                  525 non-null    object
#  13  Dirección Normalizada  688 non-null    object
#  14  COMUNA                 696 non-null    int64
#  15  XY (CABA)              696 non-null    object
#  16  pos x                  696 non-null    object
#  17  pos y                  696 non-null    object
#  18  PARTICIPANTES          696 non-null    object
#  19  VICTIMA                696 non-null    object
#  20  ACUSADO                696 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(14)
# memory usage: 114.3+ KB

# %% [markdown]
# ## Manejo de duplicados

# %% [markdown]
# Se realizó la revisión de duplicados del dataset y se encontró que no existian valores repetidos para todas las columnas

# %%
hechos[hechos.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, N_VICTIMAS, FECHA, AAAA, MM, DD, HORA, HH, LUGAR_DEL_HECHO, TIPO_DE_CALLE, Calle, Altura, Cruce, Dirección Normalizada, COMUNA, XY (CABA), pos x, pos y, PARTICIPANTES, VICTIMA, ACUSADO]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ## Manejos de nulos

# %% [markdown]
# Se encontró que existian nulos en las columnas *'Calle'*, *'Altura'*, *'Cruce'* y *'Direccion Normalizada'*. Estas columnas aportan informacion sobre la ubicacion del siniestro. De acuerdo con esto, se decidio extraer la informacion esencial que nos ofrecen estos datos. Se decidio declarar dos variables nuevas: **INTERSECCION** y **VIAS_INVOL** que se explican a continuacion.

# %%
hechos.isnull().sum()
# Out:
# ID                         0
# N_VICTIMAS                 0
# FECHA                      0
# AAAA                       0
# MM                         0
# DD                         0
# HORA                       0
# HH                         0
# LUGAR_DEL_HECHO            0
# TIPO_DE_CALLE              0
# Calle                      1
# Altura                   567
# Cruce                    171
# Dirección Normalizada      8
# COMUNA                     0
# XY (CABA)                  0
# pos x                      0
# pos y                      0
# PARTICIPANTES              0
# VICTIMA                    0
# ACUSADO                    0
# dtype: int64

# %% [markdown]
# #### Intersecciones

# %% [markdown]
# La columna __*INTERSECCION*__ indica si el siniestro se produjo en una interseccion. Para esto se observo que los hechos ocurridos en intersecciones contenian el nombre de la segunda via en la columna *Cruce* y los que ocurrian a mitad de cuadra tenian la especificacion en la columna *Altura*. Sin embargo, se encontro que existian hechos que no tenian valores en ninguna de las dos columnas antes mencionadas. Se analizo detenidamente la columna *LUGAR_DEL_HECHO* y se identifico que estos tenian una especificacion equivalente a la altura en su despripcion (en su mayoria en KM). De acuerdo con esto, se tomo que los valores en nulo de la columna *Cruce* tuvieran o no valor de *Altura* eran siniestros que no ocurrieron en una interseccion. De esta manera, se declaró esta variable como 1 para hechos en interseccion y 0 para los que no.

# %%
pd.set_option('display.max_colwidth', None)
print(hechos[(hechos['Altura'].isnull())&(hechos['Cruce'].isnull())]['LUGAR_DEL_HECHO'])
pd.reset_option('display.max_colwidth')
# Out:
# 35                                   AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI KM. 0,700
# 38                                                             AUTOPISTA LUGONES PK 10000
# 64                                       AUTOPISTA 1 SUR PTE ARTURO FRONDIZI Y AV CASEROS
# 71                                           AUTOPISTA DELLEPIANE LUIS TTE. GRAL. KM. 2,3
# 81                                                AUTOPISTA 9 DE JULIO SUR ALT AV MENDOZA
# 91                                             AUTOPISTA 1 SUR PTE ARTURO FRONDIZI KM 2.9
# 100                                                  AUTOPISTA 9 DE JULIO SUR Y AV BRASIL
# 106                                                      AU BUENOS AIRES - LA PLATA KM. 4
# 119                                                                                    SD
# 127                                                   AUTOPISTA PERITO MORENO ALTURA VELZ
# 139                                                                  AUTOPISTA 25 DE MAYO
# 148                                                             AU 25 DE MAYO Y AV. BOEDO
# 155       AU 25 DE MAYO, KILOMETRO 8.3, SENTIDO HACIA PROVINCIA DE BUENOS AIRES, C.A.B.A.
# 176                                                         AV. LEOPOLDO LUGONES PKM 6900
# 180                                               AU PERITO MORENO Y RAMAL ENLACE AU1/AU6
# 181                                                                    AU DELLEPIANE 2400
# 234                                                            AU 25 DE MAYO Y AV. VARELA
# 256                                                           AU ARTURO FRONDIZI PKM 3100
# 281                                                              AU Perito Moreno  KM 0.6
# 294                                      Fernandez de la Cruz Subida AU Héctor J. Cámpora
# 313                                                              AUTOPISTA LUGONES KM 4.7
# 346    AU Dellepiane kilometro 0.0, altura calle Montiel, sentido hacia el Centro Porteño
# 385                                       AU Perito Moreno y Av. Eva Perón SENTIDO CENTRO
# 398                                             AU Perito Moreno y Reservistas Argentinos
# 474                               AUTOPISTA PERITO MORENO ALTURA PASO A NIVEL DE IRIGOYEN
# 492            AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI ALTURA DON PEDRO DE MENDOZA AV.
# 511                         AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI ALTURA CASEROS AV.
# 513                                                        AUTOPISTA PERITO MORENO KM 5,6
# 546                                                          LUGONES, LEOPOLDO AV. KM 6,1
# 555                        AU 25 DE MAYO ALTURA PUMACAHUA Y RECUERO, CASIMIRO, TTE. CNEL.
# 559                                                                       MURGUIONDO 2700
# 585                            AUTOPISTA PERITO MORENO ALTURA ESTACION DE TREN VILLA LURO
# 599                                                                     AU FRONDIZI KM. 3
# 601                                                                 AU 25 DE MAYO KM. 3,7
# 621                                                      AU BUENOS AIRES LA PLATA  KM 4,5
# 624                                           AU FRONDIZI ALTURA QUINQUELA MARTIN, BENITO
# 631                                                 AU 25 DE MAYO ALTURA BAJADA BOEDO AV.
# 643                                                              AU FRONDIZI Y SUAREZ AV.
# 655                                              AU ILLIA KM 3.2, ALTURA CABINAS DE PEAJE
# 665                                                    AU FRONDIZI KM 2,9 (ALTURA BRASIL)
# 679                                                           AU FRONDIZI SUBIDA BRANDSEN
# 680                                                      AU 25 DE MAYO KM7 (ALTURA PASCO)
# Name: LUGAR_DEL_HECHO, dtype: object

# %%
hechos['INTERSECCION'] = hechos['Cruce'].notnull().astype(int)

# %%
hechos['INTERSECCION'].value_counts()
# Out:
# INTERSECCION
# 1    525
# 0    171
# Name: count, dtype: int64

# %%
hechos.head()
# Out:
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00  1
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00  7
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00  0
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...
# 2                         AV ENTRE RIOS 2034       AVENIDA  ...
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# 2                                  NaN
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.
#
#                                Dirección Normalizada COMUNA  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...      8
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.      9
# 2                                ENTRE RIOS AV. 2034      1
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.      8
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.      1
#
#                                  XY (CABA)         pos x         pos y  \
# 0    Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1    Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2   Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3    Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4  Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
#
#     PARTICIPANTES VICTIMA    ACUSADO INTERSECCION
# 0       MOTO-AUTO    MOTO       AUTO            1
# 1  AUTO-PASAJEROS    AUTO  PASAJEROS            1
# 2       MOTO-AUTO    MOTO       AUTO            0
# 3         MOTO-SD    MOTO         SD            1
# 4  MOTO-PASAJEROS    MOTO  PASAJEROS            1
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Vias involucradas

# %%
hechos['Calle'].unique().size
# Out:
# 280

# %%
hechos['Cruce'].unique().size
# Out:
# 318

# %%
hechos['VIAS_INVOL']=hechos.apply(lambda row: [row['Calle'], row['Cruce']] if pd.notnull(row['Cruce']) else [row['Calle']], axis=1)

# %%
hechos[['Calle','Cruce','VIAS_INVOL']]
# Out:
#                             Calle                                Cruce  \
# 0                PIEDRA BUENA AV.  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  PAZ, GRAL. AV.                  DE LOS CORRALES AV.
# 2                  ENTRE RIOS AV.                                  NaN
# 3                  LARRAZABAL AV.             VILLEGAS, CONRADO, GRAL.
# 4                    SAN JUAN AV.              SAENZ PE?A, LUIS, PRES.
# ..                            ...                                  ...
# 691                   RIESTRA AV.                                  MOM
# 692  DELLEPIANE, LUIS, TTE. GRAL.                          LACARRA AV.
# 693                     GAONA AV.                              TERRADA
# 694                PERON, EVA AV.                                  NaN
# 695           PADRE CARLOS MUJICA                                  NaN
#
#                                             VIAS_INVOL
# 0    [PIEDRA BUENA AV., FERNANDEZ DE LA CRUZ, F., G...
# 1                [PAZ, GRAL. AV., DE LOS CORRALES AV.]
# 2                                     [ENTRE RIOS AV.]
# 3           [LARRAZABAL AV., VILLEGAS, CONRADO, GRAL.]
# 4              [SAN JUAN AV., SAENZ PE?A, LUIS, PRES.]
# ..                                                 ...
# 691                                 [RIESTRA AV., MOM]
# 692        [DELLEPIANE, LUIS, TTE. GRAL., LACARRA AV.]
# 693                               [GAONA AV., TERRADA]
# 694                                   [PERON, EVA AV.]
# 695                              [PADRE CARLOS MUJICA]
#
# [696 rows x 3 columns]

# %%
hechos.drop(columns=['Calle','Cruce','Altura','Dirección Normalizada','LUGAR_DEL_HECHO'],inplace=True)

# %%
hechos.head()
# Out:
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH TIPO_DE_CALLE  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4       AVENIDA
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00  1      GRAL PAZ
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00  7       AVENIDA
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00  0       AVENIDA
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00  5       AVENIDA
#
#    COMUNA                                XY (CABA)         pos x  \
# 0       8    Point (98896.78238426 93532.43437792)  -58.47533969
# 1       9    Point (95832.05571093 95505.41641999)  -58.50877521
# 2       1   Point (106684.29090040 99706.57687843)  -58.39040293
# 3       8    Point (99840.65224780 94269.16534422)  -58.46503904
# 4       1  Point (106980.32827929 100752.16915795)  -58.38718297
#
#           pos y   PARTICIPANTES VICTIMA    ACUSADO  INTERSECCION  \
# 0  -34.68757022       MOTO-AUTO    MOTO       AUTO             1
# 1  -34.66977709  AUTO-PASAJEROS    AUTO  PASAJEROS             1
# 2  -34.63189362       MOTO-AUTO    MOTO       AUTO             0
# 3  -34.68092974         MOTO-SD    MOTO         SD             1
# 4  -34.62246630  MOTO-PASAJEROS    MOTO  PASAJEROS             1
#
#                                           VIAS_INVOL
# 0  [PIEDRA BUENA AV., FERNANDEZ DE LA CRUZ, F., G...
# 1              [PAZ, GRAL. AV., DE LOS CORRALES AV.]
# 2                                   [ENTRE RIOS AV.]
# 3         [LARRAZABAL AV., VILLEGAS, CONRADO, GRAL.]
# 4            [SAN JUAN AV., SAENZ PE?A, LUIS, PRES.]

# %% [markdown]
# ### Ubicacion geografica

# %% [markdown]
# Tambien se encontro que en las columnas **'pos x'** y **'pos y'** existian 12 registros con valores que era *'.'* lo cual es equivalente a que no existe el dato. Por esta razon se decidió revisar si existian duplicados según estas columnas y se obtuvieron 150 registros. Sin embargo, aunque fueran duplicados segun estas dos columnas el resto de la informacion era diferente. Teniendo en cuenta lo anterior se decidió imputar los datos faltantes con la moda segun cada *'COMUNA'* para no afectar la informacion segun esta caracteristica que se revisara mas adelante. En el momento de realizar esto, se encontró que existian la comuna *'0'* que no existe en la realidad. Se verificó que información contenian estos registros y se encontro que contaban en su mayoria con *'SD'* en la tabla de *'hechos'* como en la de *'victimas'* (segun el *'ID'* correspondiente). De acuerdo con esto, se decidio eliminar estos 2 registros.

# %%
hechos[(hechos['pos y']=='.')&(hechos['pos x']=='.')]
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 38   2016-0052           1 2016-04-20  2016   4  20  20:00:00  20
# 106  2016-0136           1 2016-10-25  2016  10  25  00:00:00   0
# 119  2016-0151           1 2016-11-18  2016  11  18  20:35:00  20
# 139  2016-0174           1 2016-12-27  2016  12  27  00:00:00   0
# 176  2017-0042           1 2017-04-10  2017   4  10  09:00:00   9
# 180  2017-0050           2 2017-04-28  2017   4  28  11:08:08  11
# 181  2017-0051           1 2017-05-01  2017   5   1  03:47:47   3
# 256  2017-0140           1 2017-11-19  2017  11  19  23:22:17  23
# 313  2018-0039           1 2018-04-21  2018   4  21  22:15:00  22
# 546  2020-0026           1 2020-05-17  2020   5  17  06:40:00   6
# 559  2020-0039           1 2020-09-01  2020   9   1  19:17:42  19
# 621  2021-0023           1 2021-03-01  2021   3   1  09:20:00   9
#
#     TIPO_DE_CALLE  COMUNA    XY (CABA) pos x pos y     PARTICIPANTES VICTIMA  \
# 38      AUTOPISTA      13  Point (. .)     .     .           MOTO-SD    MOTO
# 106     AUTOPISTA       4  Point (. .)     .     .       MOTO-CARGAS    MOTO
# 119         CALLE       0  Point (. .)     .     .         PEATON-SD  PEATON
# 139     AUTOPISTA       0  Point (. .)     .     .             SD-SD      SD
# 176      GRAL PAZ      14  Point (. .)     .     .       MOTO-CARGAS    MOTO
# 180     AUTOPISTA       9  Point (. .)     .     .       MOTO-CARGAS    MOTO
# 181     AUTOPISTA       7  Point (. .)     .     .         AUTO-AUTO    AUTO
# 256     AUTOPISTA       4  Point (. .)     .     .    MOTO-PASAJEROS    MOTO
# 313     AUTOPISTA      14  Point (. .)     .     .       PEATON-AUTO  PEATON
# 546     AUTOPISTA      14  Point (. .)     .     .  MOTO-OBJETO FIJO    MOTO
# 559         CALLE       9  Point (. .)     .     .     PEATON-CARGAS  PEATON
# 621     AUTOPISTA       4  Point (. .)     .     .       MOTO-CARGAS    MOTO
#
#          ACUSADO  INTERSECCION                                    VIAS_INVOL
# 38            SD             0                       [LUGONES, LEOPOLDO AV.]
# 106       CARGAS             0           [AUTOPISTA BUENOS AIRES - LA PLATA]
# 119           SD             0                                         [nan]
# 139           SD             0                        [AUTOPISTA 25 DE MAYO]
# 176       CARGAS             0                       [LUGONES, LEOPOLDO AV.]
# 180       CARGAS             0                     [AUTOPISTA PERITO MORENO]
# 181         AUTO             0        [AUTOPISTA DELLEPIANE LUIS TTE. GRAL.]
# 256    PASAJEROS             0  [AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI]
# 313         AUTO             0                       [LUGONES, LEOPOLDO AV.]
# 546  OBJETO FIJO             0                       [LUGONES, LEOPOLDO AV.]
# 559       CARGAS             0                                  [MURGUIONDO]
# 621       CARGAS             0           [AUTOPISTA BUENOS AIRES - LA PLATA]

# %%
hechos[hechos.duplicated(subset=['pos x','pos y'],keep=False)]
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 1    2016-0002           1 2016-01-02  2016   1   2  01:15:00   1
# 5    2016-0008           1 2016-01-24  2016   1  24  18:30:00  18
# 7    2016-0010           1 2016-01-29  2016   1  29  15:20:00  15
# 17   2016-0025           1 2016-02-28  2016   2  28  04:50:00   4
# 22   2016-0031           1 2016-03-08  2016   3   8  12:30:00  12
# ..         ...         ...        ...   ...  ..  ..       ...  ..
# 670  2021-0072           1 2021-09-01  2021   9   1  19:10:00  19
# 672  2021-0074           1 2021-09-20  2021   9  20  15:00:00  15
# 676  2021-0078           1 2021-10-23  2021  10  23  06:35:00   6
# 690  2021-0092           1 2021-12-12  2021  12  12  06:20:00   6
# 692  2021-0094           1 2021-12-20  2021  12  20  01:10:00   1
#
#     TIPO_DE_CALLE  COMUNA                                XY (CABA)  \
# 1        GRAL PAZ       9    Point (95832.05571093 95505.41641999)
# 5         AVENIDA       8   Point (101721.59002217 93844.25656649)
# 7        GRAL PAZ       9    Point (95832.05571093 95505.41641999)
# 17       GRAL PAZ       8   Point (100077.95205948 91571.23307293)
# 22       GRAL PAZ       8    Point (99327.01838497 92326.91130631)
# ..            ...     ...                                      ...
# 670       AVENIDA       2  Point (106445.10866138 103387.80115442)
# 672      GRAL PAZ      12   Point (96563.66494817 108815.73881056)
# 676       AVENIDA       6  Point (103255.81315650 100797.78656418)
# 690       AVENIDA       3  Point (105258.35368554 102122.93231400)
# 692     AUTOPISTA       9    Point (99624.29795829 97569.69801131)
#
#             pos x         pos y     PARTICIPANTES VICTIMA      ACUSADO  \
# 1    -58.50877521  -34.66977709    AUTO-PASAJEROS    AUTO    PASAJEROS
# 5    -58.44451316  -34.68475866  MOTO-OBJETO FIJO    MOTO  OBJETO FIJO
# 7    -58.50877521  -34.66977709         MOTO-AUTO    MOTO         AUTO
# 17   -58.46244952  -34.70524971         AUTO-AUTO    AUTO         AUTO
# 22   -58.47064556  -34.69843756    MOTO-PASAJEROS    MOTO    PASAJEROS
# ..            ...           ...               ...     ...          ...
# 670  -58.39303911  -34.59871111       PEATON-AUTO  PEATON         AUTO
# 672  -58.50073810  -34.54979510          MULTIPLE    MOTO     MULTIPLE
# 676  -58.42779702  -34.62207347    MOTO-PASAJEROS    MOTO    PASAJEROS
# 690  -58.40596860  -34.61011987       PEATON-AUTO  PEATON         AUTO
# 692  -58.46739825  -34.65117757         MOTO-AUTO    MOTO         AUTO
#
#      INTERSECCION                                   VIAS_INVOL
# 1               1        [PAZ, GRAL. AV., DE LOS CORRALES AV.]
# 5               1            [27 DE FEBRERO AV., ESCALADA AV.]
# 7               1        [PAZ, GRAL. AV., DE LOS CORRALES AV.]
# 17              1          [PAZ, GRAL. AV., 27 DE FEBRERO AV.]
# 22              1            [PAZ, GRAL. AV., ROCA, CNEL. AV.]
# ..            ...                                          ...
# 670             1                       [CALLAO AV., PARAGUAY]
# 672             1   [PAZ, GRAL. AV., BALBIN, RICARDO, DR. AV.]
# 676             1            [INDEPENDENCIA AV., LA PLATA AV.]
# 690             1              [RIVADAVIA AV., PUEYRREDON AV.]
# 692             1  [DELLEPIANE, LUIS, TTE. GRAL., LACARRA AV.]
#
# [150 rows x 18 columns]

# %%
hechos['pos x'] = hechos['pos x'].apply(lambda x: None if x== '.' else x)
hechos['pos y'] = hechos['pos y'].apply(lambda x: None if x== '.' else x)

# %%
hechos[(hechos['pos x'].isnull())&(hechos['pos y'].isnull())]['COMUNA']
# Out:
# 38     13
# 106     4
# 119     0
# 139     0
# 176    14
# 180     9
# 181     7
# 256     4
# 313    14
# 546    14
# 559     9
# 621     4
# Name: COMUNA, dtype: int64

# %%
hechos[hechos['COMUNA']==0]
# victimas[(victimas['ID']=='2016-0151)|(victimas['ID']=='2016-0174)]
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 119  2016-0151           1 2016-11-18  2016  11  18  20:35:00  20
# 139  2016-0174           1 2016-12-27  2016  12  27  00:00:00   0
#
#     TIPO_DE_CALLE  COMUNA    XY (CABA) pos x pos y PARTICIPANTES VICTIMA  \
# 119         CALLE       0  Point (. .)  None  None     PEATON-SD  PEATON
# 139     AUTOPISTA       0  Point (. .)  None  None         SD-SD      SD
#
#     ACUSADO  INTERSECCION              VIAS_INVOL
# 119      SD             0                   [nan]
# 139      SD             0  [AUTOPISTA 25 DE MAYO]

# %%
# victimas.drop(victimas[(victimas['ID']=='2016-0151)|(victimas['ID']=='2016-0174)].index,inplace=True)

# %%
hechos.drop(hechos[hechos['COMUNA']==0].index,inplace=True)

# %%
def moda_com (col,comuna):
    '''
    Funcion que retorna la moda para una comuna especifica
        Parametros: 
            col (str): nombre de la columna
            comuna (str): numero de la comuna
        Retorno: Moda de longitud/latitud para la comuna ingresada por parametro (str)
    '''
    print(comuna)
    sub = hechos[hechos['COMUNA']==int(comuna)]

    return sub[col].mode().iloc[0]

# %%
hechos['pos x'] = hechos.apply(lambda row: moda_com('pos x',str(row['COMUNA'])) if pd.isna(row['pos x']) else row['pos x'], axis=1)
hechos['pos y'] = hechos.apply(lambda row: moda_com('pos y',str(row['COMUNA'])) if pd.isna(row['pos y']) else row['pos y'], axis=1)
# Out:
# 13
# 4
# 14
# 9
# 7
# 4
# 14
# 14
# 9
# 4
# 13
# 4
# 14
# 9
# 7
# 4
# 14
# 14
# 9
# 4

# %%
hechos.isnull().sum()
# Out:
# ID               0
# N_VICTIMAS       0
# FECHA            0
# AAAA             0
# MM               0
# DD               0
# HORA             0
# HH               0
# TIPO_DE_CALLE    0
# COMUNA           0
# XY (CABA)        0
# pos x            0
# pos y            0
# PARTICIPANTES    0
# VICTIMA          0
# ACUSADO          0
# INTERSECCION     0
# VIAS_INVOL       0
# dtype: int64

# %% [markdown]
# Se realizó la trasformación de la columna **'XY (CABA)'** que indica la geodificación geografica a dos columnas *'X'* y *'Y'* para realizar la visualización sin embargo una vez se comenzó la elaboración del Dashboard se empleó unicamente la información de *'pos x'* y *'pos y'* que se renombraron a **'longitud'** y **'latitud'**, respectivamente.

# %%
#hechos['geo_norm'] = hechos['XY (CABA)'].apply(lambda x: re.sub(r"[^0-9.]", " ", str(x)).strip().split())
#hechos['X']=hechos['geo_norm'].apply(lambda x : x[0])
#hechos['Y']=hechos['geo_norm'].apply(lambda x : x[1])
#hechos.drop(columns=['XY (CABA)','geo_norm'],inplace=True)

# %%
hechos.rename(columns={'pos x':'LONGITUD','pos y':'LATITUD'},inplace=True)
hechos.drop(columns=['XY (CABA)'],inplace=True)

# %%
hechos.head()
# Out:
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH TIPO_DE_CALLE  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4       AVENIDA
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00  1      GRAL PAZ
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00  7       AVENIDA
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00  0       AVENIDA
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00  5       AVENIDA
#
#    COMUNA      LONGITUD       LATITUD   PARTICIPANTES VICTIMA    ACUSADO  \
# 0       8  -58.47533969  -34.68757022       MOTO-AUTO    MOTO       AUTO
# 1       9  -58.50877521  -34.66977709  AUTO-PASAJEROS    AUTO  PASAJEROS
# 2       1  -58.39040293  -34.63189362       MOTO-AUTO    MOTO       AUTO
# 3       8  -58.46503904  -34.68092974         MOTO-SD    MOTO         SD
# 4       1  -58.38718297  -34.62246630  MOTO-PASAJEROS    MOTO  PASAJEROS
#
#    INTERSECCION                                         VIAS_INVOL
# 0             1  [PIEDRA BUENA AV., FERNANDEZ DE LA CRUZ, F., G...
# 1             1              [PAZ, GRAL. AV., DE LOS CORRALES AV.]
# 2             0                                   [ENTRE RIOS AV.]
# 3             1         [LARRAZABAL AV., VILLEGAS, CONRADO, GRAL.]
# 4             1            [SAN JUAN AV., SAENZ PE?A, LUIS, PRES.]

# %% [markdown]
# Se realizó el cambio de tipo de dato de las columnas **'LONGITUD'** y **'LATITUD'** de *object* a *float*. Para esto fue necesario

# %%
hechos['LONGITUD'] = hechos['LONGITUD'].astype(float)
hechos['LATITUD'] = hechos['LATITUD'].astype(float)

# %% [markdown]
# Conociendo que se tiene el valor *SD* (Sin Dato) se decidió revisar los registros con este valor. Se encontró que existen registros con este valor en las columnas *'HORA'*, *'VICTIMA'* y *'ACUSADO'*

# %% [markdown]
# ### Hora

# %% [markdown]
# Teniendo en cuenta que esta es una variable que toma valores especificos, se decidió imputar estos datos con la moda de la variable.

# %%
hechos['HORA'] = hechos['HORA'].apply(lambda x: str(hechos['HORA'].mode().iloc[0]) if x== 'SD' else x)
hechos['HH'] = hechos['HH'].apply(lambda x: str(hechos['HH'].mode().iloc[0]) if x== 'SD' else x)

# %% [markdown]
# ### Acusado y Victima

# %% [markdown]
# Se encontró un total de 25 registros que tienen *'SIN DATO'* en al menos una de las dos columnas (8 en *'VICTIMA'* y 21 en *'ACUSADO'*). Debido que contenian informacion relevante en el resto de columnas, se decidió continuar con el analisis sin manipular estos registros.

# %%
hechos[(hechos['VICTIMA']=='SD')|(hechos['ACUSADO']=='SD')]
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD                 HORA  HH  \
# 3    2016-0004           1 2016-01-10  2016   1  10             00:00:00   0
# 32   2016-0045           1 2016-04-11  2016   4  11             10:25:00  10
# 35   2016-0049           1 2016-04-17  2016   4  17             00:00:00   0
# 38   2016-0052           1 2016-04-20  2016   4  20             20:00:00  20
# 57   2016-0080           1 2016-06-18  2016   6  18             06:42:00   6
# 76   2016-0101           1 2016-08-07  2016   8   7             19:42:00  19
# 83   2016-0110           1 2016-08-24  2016   8  24             20:21:00  20
# 88   2016-0115           1 2016-09-02  2016   9   2             11:50:00  11
# 92   2016-0119           1 2016-09-04  2016   9   4             06:40:00   6
# 105  2016-0135           1 2016-10-24  2016  10  24             05:00:00   5
# 112  2016-0143           1 2016-11-06  2016  11   6             04:41:00   4
# 126  2016-0159           1 2016-12-04  2016  12   4             07:21:00   7
# 160  2017-0025           1 2017-02-24  2017   2  24             17:05:00  17
# 164  2017-0029           1 2017-03-07  2017   3   7             02:15:00   2
# 197  2017-0069           1 2017-05-24  2017   5  24             14:15:00  14
# 201  2017-0074           1 2017-06-04  2017   6   4             12:50:00  12
# 214  2017-0089           1 2017-07-13  2017   7  13             12:05:00  12
# 216  2017-0091           1 2017-07-15  2017   7  15             13:00:00  13
# 269  2017-0155           1 2017-12-12  2017  12  12             21:25:41  21
# 393  2018-0119           1 2018-11-05  2018  11   5             22:35:00  22
# 397  2018-0123           1 2018-11-12  2018  11  12             03:32:00   3
# 439  2019-0022           1 2019-03-15  2019   3  15  1900-01-02 00:00:00   0
# 450  2019-0033           1 2019-04-18  2019   4  18             01:00:00   1
# 457  2019-0040           1 2019-05-09  2019   5   9             12:45:00  12
# 620  2021-0022           1 2021-02-28  2021   2  28             12:00:00  12
#
#     TIPO_DE_CALLE  COMUNA            LONGITUD             LATITUD  \
# 3         AVENIDA       8        -58.46503904        -34.68092974
# 32       GRAL PAZ      13        -58.46743471        -34.53476874
# 35      AUTOPISTA       4  -58.37714647568196  -34.63657525428238
# 38      AUTOPISTA      13        -58.46743471        -34.53476874
# 57       GRAL PAZ       9        -58.52927982        -34.63931752
# 76       GRAL PAZ       9        -58.52932872        -34.65014993
# 83        AVENIDA       9        -58.51232237        -34.65903530
# 88          CALLE      12        -58.48935041        -34.54917673
# 92        AVENIDA      12        -58.49659234        -34.56353635
# 105       AVENIDA      14        -58.42260225        -34.56403694
# 112       AVENIDA       8        -58.44451316        -34.68475866
# 126       AVENIDA       8        -58.44451316        -34.68475866
# 160       AVENIDA       7        -58.43614426        -34.65424640
# 164         CALLE       9        -58.48501341        -34.64742455
# 197      GRAL PAZ       9        -58.52173071        -34.65997463
# 201         CALLE       9        -58.52567073        -34.63787791
# 214         CALLE       9        -58.51514709        -34.64787051
# 216      GRAL PAZ      12        -58.48671535        -34.54321216
# 269       AVENIDA       7        -58.45593915        -34.62656868
# 393       AVENIDA       8        -58.43613623        -34.66292532
# 397      GRAL PAZ       9        -58.50251790        -34.67450313
# 439       AVENIDA       1        -58.39123782        -34.62352245
# 450     AUTOPISTA       1        -58.36607137        -34.62150748
# 457         CALLE       7        -58.44263580        -34.63679732
# 620       AVENIDA      13        -58.45157681        -34.55217303
#
#     PARTICIPANTES    VICTIMA ACUSADO  INTERSECCION  \
# 3         MOTO-SD       MOTO      SD             1
# 32        MOTO-SD       MOTO      SD             1
# 35          SD-SD         SD      SD             0
# 38        MOTO-SD       MOTO      SD             0
# 57        AUTO-SD       AUTO      SD             1
# 76          SD-SD         SD      SD             1
# 83      PEATON-SD     PEATON      SD             1
# 88      SD-CARGAS         SD  CARGAS             1
# 92          SD-SD         SD      SD             1
# 105     PEATON-SD     PEATON      SD             1
# 112       MOTO-SD       MOTO      SD             1
# 126       AUTO-SD       AUTO      SD             1
# 160       MOTO-SD       MOTO      SD             1
# 164       SD-AUTO         SD    AUTO             1
# 197       MOTO-SD       MOTO      SD             1
# 201         SD-SD         SD      SD             0
# 214       SD-AUTO         SD    AUTO             0
# 216       MOTO-SD       MOTO      SD             1
# 269       SD-MOTO         SD    MOTO             0
# 393     PEATON-SD     PEATON      SD             1
# 397       AUTO-SD       AUTO      SD             1
# 439       AUTO-SD       AUTO      SD             0
# 450       MOTO-SD       MOTO      SD             1
# 457       MOTO-SD       MOTO      SD             1
# 620  PASAJEROS-SD  PASAJEROS      SD             1
#
#                                             VIAS_INVOL
# 3           [LARRAZABAL AV., VILLEGAS, CONRADO, GRAL.]
# 32                [PAZ, GRAL. AV., DEL LIBERTADOR AV.]
# 35        [AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI]
# 38                             [LUGONES, LEOPOLDO AV.]
# 57                     [PAZ, GRAL. AV., RIVADAVIA AV.]
# 76                     [PAZ, GRAL. AV., CHAVEZ, JORGE]
# 83                [ALBERDI, JUAN BAUTISTA AV., CARHUE]
# 88                                   [ARIAS, TRONADOR]
# 92          [LARRALDE, CRISOLOGO AV., TRIUNVIRATO AV.]
# 105        [FIGUEROA ALCORTA, PRES. AV., PINEDO, INT.]
# 112                  [27 DE FEBRERO AV., ESCALADA AV.]
# 126                  [27 DE FEBRERO AV., ESCALADA AV.]
# 160  [FERNANDEZ DE LA CRUZ, F., GRAL. AV., RIVERA I...
# 164                                   [MOZART, TANDIL]
# 197                  [PAZ, GRAL. AV., SCHMIDL, ULRICO]
# 201                                            [CASCO]
# 214                           [LEGUIZAMON, MARTINIANO]
# 216                           [SUPERI, PAZ, GRAL. AV.]
# 269                                    [RIVADAVIA AV.]
# 393  [RABANAL, FRANCISCO, INTENDENTE AV., SAN PEDRITO]
# 397                   [PAZ, GRAL. AV., PERON, EVA AV.]
# 439                                   [ENTRE RIOS AV.]
# 450           [AUTOPISTA 25 DE MAYO, HUERGO, ING. AV.]
# 457                                  [PUAN, SANTANDER]
# 620        [DEL LIBERTADOR AV., ROOSEVELT FRANKLIN D.]

# %%
hechos[(hechos['VICTIMA']=='SD')|(hechos['ACUSADO']=='SD')].shape[0]
# Out:
# 25

# %% [markdown]
# ## Transformación de datos

# %% [markdown]
# ### Fecha del Siniestro

# %% [markdown]
# Se observaron las columnas **'FECHA'**, **'AAAA'**, **'MM'** y **'DD'** para sintetizar la información mas relevante. Se llego a la conclusión que para el analisis la informacion necesaria era el año, el mes y el dia de la semana. De acuerdo con esto, se empleó la variable *'FECHA'* para extraer el dia de la semana en nombre (guardada en la variable **'DIA_SEMANA_NOM'**) y en numero (guardada en la variable **'DIA_SEMANA'**) que se declaro de la siguiente semana:
# - 0 = Lunes
# - 1 = Martes
# - 2 = Miercoles
# - 3 = Jueves
# - 4 = Viernes
# - 5 = Sábado
# - 6 = Domingo
#
# Una vez se creó esta columna, se decidió borrar las columnas *'FECHA'* y *'DD'** y se renombraron las columnas *'AAAA'* a *'AÑO'* y *'MM'* a *'MES'*.

# %%
hechos['DIA_SEMANA_NOM'] = hechos['FECHA'].dt.strftime('%A').str.upper()
hechos['DIA_SEMANA'] = hechos['FECHA'].dt.weekday

# %%
hechos.rename(columns={'AAAA':'AÑO','MM':'MES'},inplace=True)
hechos.drop(columns=['DD','FECHA'],inplace=True)

# %%
hechos.head()
# Out:
#           ID  N_VICTIMAS   AÑO  MES      HORA HH TIPO_DE_CALLE  COMUNA  \
# 0  2016-0001           1  2016    1  04:00:00  4       AVENIDA       8
# 1  2016-0002           1  2016    1  01:15:00  1      GRAL PAZ       9
# 2  2016-0003           1  2016    1  07:00:00  7       AVENIDA       1
# 3  2016-0004           1  2016    1  00:00:00  0       AVENIDA       8
# 4  2016-0005           1  2016    1  05:20:00  5       AVENIDA       1
#
#        LONGITUD       LATITUD   PARTICIPANTES VICTIMA    ACUSADO  \
# 0  -58.47533969  -34.68757022       MOTO-AUTO    MOTO       AUTO
# 1  -58.50877521  -34.66977709  AUTO-PASAJEROS    AUTO  PASAJEROS
# 2  -58.39040293  -34.63189362       MOTO-AUTO    MOTO       AUTO
# 3  -58.46503904  -34.68092974         MOTO-SD    MOTO         SD
# 4  -58.38718297  -34.62246630  MOTO-PASAJEROS    MOTO  PASAJEROS
#
#    INTERSECCION                                         VIAS_INVOL  \
# 0             1  [PIEDRA BUENA AV., FERNANDEZ DE LA CRUZ, F., G...
# 1             1              [PAZ, GRAL. AV., DE LOS CORRALES AV.]
# 2             0                                   [ENTRE RIOS AV.]
# 3             1         [LARRAZABAL AV., VILLEGAS, CONRADO, GRAL.]
# 4             1            [SAN JUAN AV., SAENZ PE?A, LUIS, PRES.]
#
#   DIA_SEMANA_NOM  DIA_SEMANA
# 0        VIERNES           4
# 1         SÁBADO           5
# 2        DOMINGO           6
# 3        DOMINGO           6
# 4         JUEVES           3

# %% [markdown]
# ### Hora del Siniestro

# %% [markdown]
# Para la hora se decidió utilizar la información que se encontraba en la columna **'HORA'**, pero transformandolo a tipo *float* para tener mayor precision que la columna *'HH'*. De acuerdo con esto, se elimino esta ultima columna.

# %%
hechos['HORA']=pd.to_datetime(hechos['HORA'], format='%H:%M:%S')

# %%
hechos['HORA']=hechos['HORA'].dt.hour + hechos['HORA'].dt.minute / 60

# %% [markdown]
# Se verificó que no existieran valores menores a 0 o mayores a 24, ya que se estaba empleando el formato de 24 horas para representar la hora del dia.

# %%
hechos['HORA'].describe()
# Out:
# count    694.000000
# mean      12.030379
# std        6.689003
# min        0.000000
# 25%        6.500000
# 50%       11.583333
# 75%       17.912500
# max       23.750000
# Name: HORA, dtype: float64

# %%
hechos.drop(columns='HH',inplace=True)

# %%
hechos.head()
# Out:
#           ID  N_VICTIMAS   AÑO  MES      HORA TIPO_DE_CALLE  COMUNA  \
# 0  2016-0001           1  2016    1  4.000000       AVENIDA       8
# 1  2016-0002           1  2016    1  1.250000      GRAL PAZ       9
# 2  2016-0003           1  2016    1  7.000000       AVENIDA       1
# 3  2016-0004           1  2016    1  0.000000       AVENIDA       8
# 4  2016-0005           1  2016    1  5.333333       AVENIDA       1
#
#        LONGITUD       LATITUD   PARTICIPANTES VICTIMA    ACUSADO  \
# 0  -58.47533969  -34.68757022       MOTO-AUTO    MOTO       AUTO
# 1  -58.50877521  -34.66977709  AUTO-PASAJEROS    AUTO  PASAJEROS
# 2  -58.39040293  -34.63189362       MOTO-AUTO    MOTO       AUTO
# 3  -58.46503904  -34.68092974         MOTO-SD    MOTO         SD
# 4  -58.38718297  -34.62246630  MOTO-PASAJEROS    MOTO  PASAJEROS
#
#    INTERSECCION                                         VIAS_INVOL  \
# 0             1  [PIEDRA BUENA AV., FERNANDEZ DE LA CRUZ, F., G...
# 1             1              [PAZ, GRAL. AV., DE LOS CORRALES AV.]
# 2             0                                   [ENTRE RIOS AV.]
# 3             1         [LARRAZABAL AV., VILLEGAS, CONRADO, GRAL.]
# 4             1            [SAN JUAN AV., SAENZ PE?A, LUIS, PRES.]
#
#   DIA_SEMANA_NOM  DIA_SEMANA
# 0        VIERNES           4
# 1         SÁBADO           5
# 2        DOMINGO           6
# 3        DOMINGO           6
# 4         JUEVES           3

# %% [markdown]
# ## Reordenamiento de columnas

# %% [markdown]
# Se decidió reordenar las columnas de manera que las columnas con informacion nueva estuvieran cerca de las columnas relacionadas (ej. *'DIA_SEMANA'* con *'AÑO'* y *'MES'*)

# %%
hechos = hechos[['ID','N_VICTIMAS', 'AÑO', 'MES','DIA_SEMANA','DIA_SEMANA_NOM','HORA','TIPO_DE_CALLE','VIAS_INVOL','INTERSECCION','COMUNA','PARTICIPANTES','VICTIMA', 'ACUSADO','LONGITUD', 'LATITUD']]

# %%
hechos.head(10)
# Out:
#           ID  N_VICTIMAS   AÑO  MES  DIA_SEMANA DIA_SEMANA_NOM       HORA  \
# 0  2016-0001           1  2016    1           4        VIERNES   4.000000
# 1  2016-0002           1  2016    1           5         SÁBADO   1.250000
# 2  2016-0003           1  2016    1           6        DOMINGO   7.000000
# 3  2016-0004           1  2016    1           6        DOMINGO   0.000000
# 4  2016-0005           1  2016    1           3         JUEVES   5.333333
# 5  2016-0008           1  2016    1           6        DOMINGO  18.500000
# 6  2016-0009           1  2016    1           6        DOMINGO  19.166667
# 7  2016-0010           1  2016    1           4        VIERNES  15.333333
# 8  2016-0012           1  2016    2           0          LUNES   1.333333
# 9  2016-0013           1  2016    2           2      MIÉRCOLES  11.500000
#
#   TIPO_DE_CALLE                                         VIAS_INVOL  \
# 0       AVENIDA  [PIEDRA BUENA AV., FERNANDEZ DE LA CRUZ, F., G...
# 1      GRAL PAZ              [PAZ, GRAL. AV., DE LOS CORRALES AV.]
# 2       AVENIDA                                   [ENTRE RIOS AV.]
# 3       AVENIDA         [LARRAZABAL AV., VILLEGAS, CONRADO, GRAL.]
# 4       AVENIDA            [SAN JUAN AV., SAENZ PE?A, LUIS, PRES.]
# 5       AVENIDA                  [27 DE FEBRERO AV., ESCALADA AV.]
# 6         CALLE                     [NOGOYA, GONZALEZ, JOAQUIN V.]
# 7      GRAL PAZ              [PAZ, GRAL. AV., DE LOS CORRALES AV.]
# 8       AVENIDA              [BELGRANO AV., IRIGOYEN, BERNARDO DE]
# 9       AVENIDA                                   [ENTRE RIOS AV.]
#
#    INTERSECCION  COMUNA     PARTICIPANTES VICTIMA      ACUSADO      LONGITUD  \
# 0             1       8         MOTO-AUTO    MOTO         AUTO  -58.47533969
# 1             1       9    AUTO-PASAJEROS    AUTO    PASAJEROS  -58.50877521
# 2             0       1         MOTO-AUTO    MOTO         AUTO  -58.39040293
# 3             1       8           MOTO-SD    MOTO           SD  -58.46503904
# 4             1       1    MOTO-PASAJEROS    MOTO    PASAJEROS  -58.38718297
# 5             1       8  MOTO-OBJETO FIJO    MOTO  OBJETO FIJO  -58.44451316
# 6             1      11         MOTO-AUTO    MOTO         AUTO  -58.50095869
# 7             1       9         MOTO-AUTO    MOTO         AUTO  -58.50877521
# 8             1       1       MOTO-CARGAS    MOTO       CARGAS  -58.38048577
# 9             0       1       PEATON-AUTO  PEATON         AUTO  -58.39114932
#
#         LATITUD
# 0  -34.68757022
# 1  -34.66977709
# 2  -34.63189362
# 3  -34.68092974
# 4  -34.62246630
# 5  -34.68475866
# 6  -34.60825440
# 7  -34.66977709
# 8  -34.61303893
# 9  -34.62477387

# %% [markdown]
# ## Tipo de dato

# %% [markdown]
# Al finalizar la limpieza y normalización del DataFrame se tienen 4 tipos de datos para este dataset:
# - **Object (string):** *'ID'*, *'DIA_SEMANA_NOM'*, *'TIPO_DE_CALLE'*, *'PARTICIPANTES'*, *'VICTIMA'*, *'ACUSADO'*
# - **Object (list):** *'VIAS_INVOL'*
# - **Float:** *'HORA'*, *'LONGITUD'*, *'LATITUD'*
# - **Int:** *'N_VICTIMAS'*, *'AÑO'*, *'MES'*, *'COMUNA'*, *'INTERSECCION'*, *'DIA_SEMANA'*

# %%
hechos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 694 entries, 0 to 695
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              694 non-null    object
#  1   N_VICTIMAS      694 non-null    int64
#  2   AÑO             694 non-null    int64
#  3   MES             694 non-null    int64
#  4   DIA_SEMANA      694 non-null    int32
#  5   DIA_SEMANA_NOM  694 non-null    object
#  6   HORA            694 non-null    float64
#  7   TIPO_DE_CALLE   694 non-null    object
#  8   VIAS_INVOL      694 non-null    object
#  9   INTERSECCION    694 non-null    int64
#  10  COMUNA          694 non-null    int64
#  11  PARTICIPANTES   694 non-null    object
#  12  VICTIMA         694 non-null    object
#  13  ACUSADO         694 non-null    object
#  14  LONGITUD        694 non-null    float64
#  15  LATITUD         694 non-null    float64
# dtypes: float64(3), int32(1), int64(5), object(7)
# memory usage: 89.5+ KB

# %% [markdown]
# ## Analisis de Variables

# %% [markdown]
# #### Numero de victimas

# %%
hechos['N_VICTIMAS'].value_counts()
# Out:
# N_VICTIMAS
# 1    674
# 2     19
# 3      1
# Name: count, dtype: int64

# %%
counts, bins, patches = plt.bar(hechos['N_VICTIMAS'].value_counts().index, 
                                hechos['N_VICTIMAS'].value_counts().values)

plt.xticks(ticks=[1, 2, 3], labels=hechos['N_VICTIMAS'].value_counts().index)
plt.xlabel('Numero de Homicidios',fontweight='bold')

plt.title("Histograma de cantidad de homicidios por Siniestro Vial", fontsize=18, fontweight='bold')

for index, value in enumerate(hechos['N_VICTIMAS'].value_counts().values):
    plt.text(index + 1, value + 10, str(value), ha='center', va='bottom', fontsize=10)

plt.show()

# %%
plt.pie(hechos['N_VICTIMAS'].value_counts(),autopct='%1.1f%%')
plt.title('Proporcion de numero de victimas por Siniestro Vial',fontsize=15,fontweight='bold',loc='center')
plt.legend(['1','2','3'],title='Cantidad de homicidios',loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# #### Año

# %%
vict_anio = hechos.groupby(['AÑO']).agg({'N_VICTIMAS':'sum'})

plt.bar(vict_anio.index,vict_anio.values.flatten())
plt.xlabel('Año',fontweight='bold')
plt.title("Homicidios por Siniestro Vial por Año", fontsize=18, fontweight='bold')
plt.ylabel('Número de Homicidios', fontweight='bold')

for index, value in enumerate(vict_anio.values.flatten()):
    plt.text(vict_anio.index[index], value + 2, str(int(value)), ha='center')

# %% [markdown]
# #### Mes

# %%
vict_mes = hechos.groupby(['MES']).agg({'N_VICTIMAS':'sum'})

plt.figure(figsize=(12,6))
plt.bar(vict_mes.index,vict_mes.values.flatten())
plt.xlabel('Mes',fontweight='bold')
plt.xticks(labels=['ENE','FEB','MAR','ABR','MAY','JUN','JUL','AGO','SEP','OCT','NOV','DIC'],ticks=vict_mes.index)
plt.title("Homicidios por Siniestro Vial por Mes", fontsize=18, fontweight='bold')
plt.ylabel('Número de Homicidios', fontweight='bold')

for index, value in enumerate(vict_mes.values.flatten()):
    plt.text(vict_mes.index[index], value + 2, str(int(value)), ha='center')

# %%
vict_mes_p = vict_mes/6
plt.figure(figsize=(12,6))
plt.bar(vict_mes_p.index,vict_mes_p.values.flatten())
plt.xlabel('Mes',fontweight='bold')
plt.xticks(labels=['ENE','FEB','MAR','ABR','MAY','JUN','JUL','AGO','SEP','OCT','NOV','DIC'],ticks=vict_mes_p.index)
plt.title("Homicidios PROMEDIO por Siniestro Vial por Mes", fontsize=18, fontweight='bold')
plt.ylabel('Número de Homicidios', fontweight='bold')

for index, value in enumerate(vict_mes_p.values.flatten()):
    plt.text(vict_mes_p.index[index], value+0.3, str(int(value)), ha='center')

# %%
vict_anio_mes = hechos.groupby(['MES', 'AÑO']).agg({'N_VICTIMAS': 'sum'}).unstack()

# Definir los datos de víctimas por mes y año
vict_2016 = vict_anio_mes[('N_VICTIMAS', 2016)].values.flatten()
vict_2017 = vict_anio_mes[('N_VICTIMAS', 2017)].values.flatten()
vict_2018 = vict_anio_mes[('N_VICTIMAS', 2018)].values.flatten()
vict_2019 = vict_anio_mes[('N_VICTIMAS', 2019)].values.flatten()
vict_2020 = vict_anio_mes[('N_VICTIMAS', 2020)].values.flatten()
vict_2021 = vict_anio_mes[('N_VICTIMAS', 2021)].values.flatten()

# Crear figura y gráfico de barras apiladas
plt.figure(figsize=(12, 6))
plt.bar(vict_anio_mes.index, vict_2016, label='2016')
plt.bar(vict_anio_mes.index, vict_2017, bottom=vict_2016, label='2017')
plt.bar(vict_anio_mes.index, vict_2018, bottom=vict_2016 + vict_2017, label='2018')
plt.bar(vict_anio_mes.index, vict_2019, bottom=vict_2016 + vict_2017 + vict_2018, label='2019')
plt.bar(vict_anio_mes.index, vict_2020, bottom=vict_2016 + vict_2017 + vict_2018 + vict_2019, label='2020')
plt.bar(vict_anio_mes.index, vict_2021, bottom=vict_2016 + vict_2017 + vict_2018 + vict_2019 + vict_2020, label='2021')

# Etiquetas y título
plt.xticks(labels=['ENE', 'FEB', 'MAR', 'ABR', 'MAY', 'JUN', 'JUL', 'AGO', 'SEP', 'OCT', 'NOV', 'DIC'], ticks=vict_anio_mes.index)
plt.xlabel('Mes', fontweight='bold')
plt.ylabel('Número de Homicidios', fontweight='bold')
plt.title('Homicidios por Siniestro Vial por Mes', fontsize=18, fontweight='bold')

# Añadir leyenda para identificar los años
plt.legend(title='Año',loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))

# Mostrar gráfico
plt.show()

# %% [markdown]
# #### Dia de la semana

# %% [markdown]
# Se realizó el analisis por dia de la semana usando la columna numerica (**'DIA_SEMANA'**) y la del nombre se usara en el momento de elaborar el Dasshboard en PowerBI

# %%
vict_anio_dia = hechos.groupby(['DIA_SEMANA', 'AÑO']).agg({'N_VICTIMAS': 'sum'}).unstack()

# Definir los datos de víctimas por mes y año
vict_2016_d = vict_anio_dia[('N_VICTIMAS', 2016)].values.flatten()
vict_2017_d = vict_anio_dia[('N_VICTIMAS', 2017)].values.flatten()
vict_2018_d = vict_anio_dia[('N_VICTIMAS', 2018)].values.flatten()
vict_2019_d = vict_anio_dia[('N_VICTIMAS', 2019)].values.flatten()
vict_2020_d = vict_anio_dia[('N_VICTIMAS', 2020)].values.flatten()
vict_2021_d = vict_anio_dia[('N_VICTIMAS', 2021)].values.flatten()

# Crear figura y gráfico de barras apiladas
plt.figure(figsize=(12, 6))
plt.bar(vict_anio_dia.index, vict_2016_d, label='2016')
plt.bar(vict_anio_dia.index, vict_2017_d, bottom=vict_2016_d, label='2017')
plt.bar(vict_anio_dia.index, vict_2018_d, bottom=vict_2016_d + vict_2017_d, label='2018')
plt.bar(vict_anio_dia.index, vict_2019_d, bottom=vict_2016_d + vict_2017_d + vict_2018_d, label='2019')
plt.bar(vict_anio_dia.index, vict_2020_d, bottom=vict_2016_d + vict_2017_d + vict_2018_d + vict_2019_d, label='2020')
plt.bar(vict_anio_dia.index, vict_2021_d, bottom=vict_2016_d + vict_2017_d + vict_2018_d + vict_2019_d + vict_2020_d, label='2021')

# Etiquetas y título
plt.xticks(labels=['LUN', 'MAR', 'MIE', 'JUE', 'VIE', 'SAB', 'DOM'], ticks=vict_anio_dia.index)
plt.xlabel('Dia de la Semana', fontweight='bold')
plt.ylabel('Número de Homicidios', fontweight='bold')
plt.title('Homicidios por Siniestro Vial por Dia de la Semana', fontsize=18, fontweight='bold')

# Añadir leyenda para identificar los años
plt.legend(title='Año',loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))

# Mostrar gráfico
plt.show()

# %% [markdown]
# #### Hora

# %%
plt.figure(figsize=(12, 6))
plt.hist(hechos['HORA'],rwidth=0.8,bins=24)
plt.title('Homicidios por Siniestro Vial por Hora del Dia', fontsize=18, fontweight='bold')
plt.xlabel('Hora del dia', fontweight='bold')
plt.ylabel('Cantidad de Homicidios', fontweight='bold')
plt.xticks(ticks=range(0,25))
plt.show()

# %% [markdown]
# #### Tipo de Calle

# %%
hechos['TIPO_DE_CALLE'].value_counts()
# Out:
# TIPO_DE_CALLE
# AVENIDA      429
# CALLE        135
# GRAL PAZ      65
# AUTOPISTA     65
# Name: count, dtype: int64

# %%
plt.pie(hechos['TIPO_DE_CALLE'].value_counts(),autopct='%1.1f%%')
plt.title('Proporcion de homicidios por Tipo de Calle',fontsize=15,fontweight='bold',loc='center')
plt.legend(['Avenida',
            'Calle',
            'Autopista',
            'Gral. Paz'
],loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Vias Involucradas

# %% [markdown]
# Se realizó un analisis para identificar cuales son las vias en las que se ha presentado la mayor cantidad de homicidios por Siniestro Vial. Para esto se creo una funcion que permite sacar una lista de frecuencia de las vias involucradas

# %%
def frec_unicos(col):
    ''' 
    Funcion que devuelve los valores unicos y las frecuencias de los elementos de las listas que conforman una columna
        Parametros: 
            col (pn.ndarray o list): Columna que se desea procesar 
        Retorno: Tabla de frecuencia (pd.Series)'''
    u = []
    for sublist in col:
        if type(sublist)==np.ndarray or type(sublist)==list:
            for genre in sublist:
                u.append(genre)
    return pd.Series(u).value_counts()

# %%
frec_vias=frec_unicos(hechos['VIAS_INVOL'])

# %%
frec_vias
# Out:
# PAZ, GRAL. AV.                                71
# RIVADAVIA AV.                                 27
# DEL LIBERTADOR AV.                            24
# ALBERDI, JUAN BAUTISTA AV.                    18
# AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI    16
#                                               ..
# COREA AV.                                      1
# TORRES Y TENORIO, PRES.                        1
# CASARES AV.                                    1
# PILAR                                          1
# PADRE CARLOS MUJICA                            1
# Name: count, Length: 465, dtype: int64

# %% [markdown]
# Se obtuvo que en total para estos años de analisis existen 465 vias diferentes que se encontraron relacionadas con el lugar del hecho. A continuacion se presenta un grafico con las 15 vias en las que se presentaron mas siniestros.

# %%
plt.subplots_adjust(left=0.2, right=1.8,top=1.2)
plt.barh(frec_vias.head(15).index,frec_vias.head(15).values,color='skyblue')
plt.gca().invert_yaxis()
plt.title('Top 15 de Vias involucradas en los siniestros viales', fontweight = 'bold',fontsize=20)
for index, value in enumerate(frec_vias.head(15).values):
    plt.text(value+0.2, index, str(value), va='center')
plt.show()

# %% [markdown]
# ### Interseccion

# %%
plt.pie(hechos['INTERSECCION'].value_counts(),autopct='%1.1f%%',colors=['deepskyblue','gold'])
plt.title('Proporcion de homicidios por Siniestro Vial',fontsize=15,fontweight='bold',loc='center')
plt.legend(['Interseccion',
            'En cuadra'
],loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %%
vict_int_cll = hechos.groupby(['TIPO_DE_CALLE','INTERSECCION']).agg({'N_VICTIMAS': 'sum'}).unstack()
vict_int_cll
# Out:
#               N_VICTIMAS
# INTERSECCION           0    1
# TIPO_DE_CALLE
# AUTOPISTA             40   27
# AVENIDA               80  362
# CALLE                 45   92
# GRAL PAZ              10   59

# %%
# Definir los datos de víctimas por mes y año
inter = vict_int_cll[('N_VICTIMAS', 1)].values.flatten()
no_inter = vict_int_cll[('N_VICTIMAS', 0)].values.flatten()

# Crear figura y gráfico de barras apiladas
plt.figure(figsize=(12, 6))
plt.bar(vict_int_cll.index, inter, label='Interseccion', color='deepskyblue')
plt.bar(vict_int_cll.index, no_inter, bottom=inter, label='En Cuadra', color='gold')


# Etiquetas y título
plt.xticks( ticks=vict_int_cll.index)
plt.xlabel('Tipo de Calle', fontweight='bold')
plt.ylabel('Número de Homicidios', fontweight='bold')
plt.title('Cantidad de homicidios por Tipo de Calle y Ubicacion', fontsize=18, fontweight='bold')

# Añadir leyenda para identificar los años
plt.legend(title='Ubicacion',loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))

# Mostrar gráfico
plt.show()

# %%
# Se creo un DaataFrame auxiliar para poder identificar como se distibuyen el numero de sinistros por via segun si ocurrienron en una interseccion o no
vias = frec_vias
inter = frec_unicos(hechos[hechos['INTERSECCION']==1]['VIAS_INVOL'])
no_inter = frec_unicos(hechos[hechos['INTERSECCION']==0]['VIAS_INVOL'])
vias_inv = pd.DataFrame({'Vía': vias.index,'Total': vias.values,'Intersección': inter.reindex(vias.index, fill_value=0).values,'En Cuadra': no_inter.reindex(vias.index, fill_value=0).values})

# %%
vias_inv=vias_inv.sort_values('Total',ascending=False)
vias_inv
# Out:
#                                             Vía  Total  Intersección  \
# 0                                PAZ, GRAL. AV.     71            63
# 1                                 RIVADAVIA AV.     27            19
# 2                            DEL LIBERTADOR AV.     24            21
# 3                    ALBERDI, JUAN BAUTISTA AV.     18            15
# 4    AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI     16             3
# ..                                          ...    ...           ...
# 428                        ROFFO, ANGEL H., DR.      1             1
# 429             ANCHORENA, TOMAS MANUEL DE, DR.      1             1
# 430                             DIAZ, CNEL. AV.      1             1
# 431                                   DIAZ, ANA      1             1
# 457                                      POTOSI      1             1
#
#      En Cuadra
# 0            8
# 1            8
# 2            3
# 3            3
# 4           13
# ..         ...
# 428          0
# 429          0
# 430          0
# 431          0
# 457          0
#
# [465 rows x 4 columns]

# %%
# Crear el gráfico de barras apiladas
plt.figure(figsize=(12, 8))
plt.barh(vias_inv['Vía'].head(15), vias_inv['Intersección'].head(15), color='deepskyblue', label='Intersección')
plt.barh(vias_inv['Vía'].head(15), vias_inv['En Cuadra'].head(15), left=vias_inv['Intersección'].head(15), color='gold', label='En Cuadra')


plt.xlabel("Cantidad de homicidios",fontweight='bold',fontsize=12)
plt.title("Top 15 de vias involucradas (Interseccion vs. En cuadra)", fontweight='bold', fontsize=20)
plt.gca().invert_yaxis()
plt.legend(title='Recomendado',title_fontsize=15,fontsize=12)
plt.show()

# %% [markdown]
# ### Comuna

# %%
plt.subplots_adjust(left=0.2, right=1.8,top=1.2)
plt.barh(hechos['COMUNA'].value_counts().index,hechos['COMUNA'].value_counts().values,color='skyblue')
plt.gca().invert_yaxis()
plt.title('Siniestros viales por Comuna', fontweight = 'bold',fontsize=20)
plt.yticks(ticks=hechos['COMUNA'].value_counts().index)
plt.ylabel('Numero de Comuna',fontweight = 'bold',fontsize=12)
plt.xlabel('Cantidad de Siniestros Viales',fontweight = 'bold',fontsize=12)

comuna_counts = hechos['COMUNA'].value_counts().sort_index()
for index, value in enumerate(comuna_counts.values):
    plt.text(value+0.2, index+1, str(value), va='center')
plt.show()

# %% [markdown]
# ### Participantes

# %% [markdown]
# Existen 41 combinaciones diferentes entre tipo de victima y de acusado. Se decidio graficar las 15 que mas se presentan.

# %%
hechos['PARTICIPANTES'].unique().size
# Out:
# 41

# %%
plt.subplots_adjust(left=0.2, right=1.8,top=1.2)
plt.barh(hechos['PARTICIPANTES'].value_counts().head(15).index,hechos['PARTICIPANTES'].value_counts().head(15).values,color='skyblue')
plt.gca().invert_yaxis()
plt.title('Siniestros viales por combinacion de PARTICIPANTES', fontweight = 'bold',fontsize=20)
plt.yticks(ticks=hechos['PARTICIPANTES'].value_counts().head(15).index)
plt.ylabel('Tipo de PARTICIPANTES',fontweight = 'bold',fontsize=12)
plt.xlabel('Cantidad de Siniestros Viales',fontweight = 'bold',fontsize=12)

PARTICIPANTES_counts = hechos['PARTICIPANTES'].value_counts().head(15).sort_values(ascending=False)
for index, value in enumerate(PARTICIPANTES_counts.values):
    plt.text(value, index, str(value), va='center')
plt.show()

# %% [markdown]
# ### Victima

# %% [markdown]
# Se encontró un valor en la columna **VICTIMA** que no corresponde a la informacion presentada en el diccionario de datoa. Se revisó el registro y determinó que correpondia a un valor del tipo de la columna *'PARTICIPANTES'* donde se encuentra la victima y el acusado. El valor encontrado era 'PEATON_MOTO' y el *'ACUSADO'* para este registro era *MOTO*. De acuerdo con esto se asumió que el valor correcto de *'VICTIMA'* era *PEATON* y se realizo el cambio.

# %%
hechos['VICTIMA'].value_counts()
# Out:
# VICTIMA
# MOTO           295
# PEATON         263
# AUTO            83
# BICICLETA       29
# SD               8
# CARGAS           7
# PASAJEROS        5
# MOVIL            2
# OBJETO FIJO      1
# PEATON_MOTO      1
# Name: count, dtype: int64

# %%
hechos[hechos['VICTIMA']=='PEATON_MOTO']
# Out:
#             ID  N_VICTIMAS   AÑO  MES  DIA_SEMANA DIA_SEMANA_NOM      HORA  \
# 583  2020-0063           2  2020   12           5         SÁBADO  7.166667
#
#     TIPO_DE_CALLE                 VIAS_INVOL  INTERSECCION  COMUNA  \
# 583         CALLE  [NUEVA YORK, ALTA GRACIA]             1      11
#
#         PARTICIPANTES      VICTIMA ACUSADO   LONGITUD   LATITUD
# 583  PEATON_MOTO-MOTO  PEATON_MOTO    MOTO -58.527838 -34.61047

# %%
hechos.loc[(hechos['VICTIMA']=='PEATON_MOTO'),'VICTIMA']='PEATON'

# %%
plt.subplots_adjust(left=0.2, right=1.8,top=1.2)
plt.barh(hechos['VICTIMA'].value_counts().index,hechos['VICTIMA'].value_counts().values,color='skyblue')
plt.gca().invert_yaxis()
plt.title('Siniestros viales por VICTIMA', fontweight = 'bold',fontsize=20)
plt.yticks(ticks=hechos['VICTIMA'].value_counts().index)
plt.ylabel('Tipo de Victima',fontweight = 'bold',fontsize=12)
plt.xlabel('Cantidad de Siniestros Viales',fontweight = 'bold',fontsize=12)

VICTIMA_counts = hechos['VICTIMA'].value_counts().sort_values(ascending=False)
for index, value in enumerate(VICTIMA_counts.values):
    plt.text(value, index, str(value), va='center')
plt.show()

# %% [markdown]
# ### Acusado

# %%
hechos['ACUSADO'].value_counts()
# Out:
# ACUSADO
# AUTO           204
# PASAJEROS      173
# CARGAS         146
# OBJETO FIJO     62
# MOTO            57
# SD              21
# MULTIPLE        17
# BICICLETA        7
# OTRO             6
# TREN             1
# Name: count, dtype: int64

# %%
plt.subplots_adjust(left=0.2, right=1.8,top=1.2)
plt.barh(hechos['ACUSADO'].value_counts().index,hechos['ACUSADO'].value_counts().values,color='skyblue')
plt.gca().invert_yaxis()
plt.title('Siniestros viales por ACUSADO', fontweight = 'bold',fontsize=20)
plt.yticks(ticks=hechos['ACUSADO'].value_counts().index)
plt.ylabel('Tipo de Acusado',fontweight = 'bold',fontsize=12)
plt.xlabel('Cantidad de Siniestros Viales',fontweight = 'bold',fontsize=12)

ACUSADO_counts = hechos['ACUSADO'].value_counts().sort_values(ascending=False)
for index, value in enumerate(ACUSADO_counts.values):
    plt.text(value, index, str(value), va='center')
plt.show()

# %% [markdown]
# ## Analisis de Correlacion

# %%
hechos_corr = hechos[['N_VICTIMAS', 'AÑO', 'MES', 'DIA_SEMANA','HORA', 'INTERSECCION', 'COMUNA']]

# %%
corre = hechos_corr.corr()
corre
# Out:
#               N_VICTIMAS       AÑO       MES  DIA_SEMANA      HORA  \
# N_VICTIMAS      1.000000 -0.048160 -0.005072    0.092778 -0.090650
# AÑO            -0.048160  1.000000 -0.042237   -0.016295 -0.046271
# MES            -0.005072 -0.042237  1.000000   -0.064151  0.034835
# DIA_SEMANA      0.092778 -0.016295 -0.064151    1.000000 -0.044164
# HORA           -0.090650 -0.046271  0.034835   -0.044164  1.000000
# INTERSECCION   -0.016573 -0.076148 -0.025717    0.087640  0.010087
# COMUNA          0.006645  0.002882  0.054147    0.016090 -0.040415
#
#               INTERSECCION    COMUNA
# N_VICTIMAS       -0.016573  0.006645
# AÑO              -0.076148  0.002882
# MES              -0.025717  0.054147
# DIA_SEMANA        0.087640  0.016090
# HORA              0.010087 -0.040415
# INTERSECCION      1.000000  0.031091
# COMUNA            0.031091  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corre,cmap='coolwarm',center=0)
plt.show()

# %%
dummies = pd.get_dummies(hechos[['TIPO_DE_CALLE', 'VICTIMA', 'ACUSADO']])
hechos_corr = pd.concat([hechos_corr, dummies], axis=1)
hechos_corr
# Out:
#      N_VICTIMAS   AÑO  MES  DIA_SEMANA       HORA  INTERSECCION  COMUNA  \
# 0             1  2016    1           4   4.000000             1       8
# 1             1  2016    1           5   1.250000             1       9
# 2             1  2016    1           6   7.000000             0       1
# 3             1  2016    1           6   0.000000             1       8
# 4             1  2016    1           3   5.333333             1       1
# ..          ...   ...  ...         ...        ...           ...     ...
# 691           1  2021   12           0  17.166667             1       7
# 692           1  2021   12           0   1.166667             1       9
# 693           1  2021   12           3   0.716667             1      11
# 694           1  2021   12           2  10.500000             0       9
# 695           1  2021   11           3   6.166667             0       1
#
#      TIPO_DE_CALLE_AUTOPISTA  TIPO_DE_CALLE_AVENIDA  TIPO_DE_CALLE_CALLE  ...  \
# 0                      False                   True                False  ...
# 1                      False                  False                False  ...
# 2                      False                   True                False  ...
# 3                      False                   True                False  ...
# 4                      False                   True                False  ...
# ..                       ...                    ...                  ...  ...
# 691                    False                   True                False  ...
# 692                     True                  False                False  ...
# 693                    False                   True                False  ...
# 694                    False                   True                False  ...
# 695                    False                  False                 True  ...
#
#      ACUSADO_AUTO  ACUSADO_BICICLETA  ACUSADO_CARGAS  ACUSADO_MOTO  \
# 0            True              False           False         False
# 1           False              False           False         False
# 2            True              False           False         False
# 3           False              False           False         False
# 4           False              False           False         False
# ..            ...                ...             ...           ...
# 691          True              False           False         False
# 692          True              False           False         False
# 693         False              False            True         False
# 694         False              False            True         False
# 695          True              False           False         False
#
#      ACUSADO_MULTIPLE  ACUSADO_OBJETO FIJO  ACUSADO_OTRO  ACUSADO_PASAJEROS  \
# 0               False                False         False              False
# 1               False                False         False               True
# 2               False                False         False              False
# 3               False                False         False              False
# 4               False                False         False               True
# ..                ...                  ...           ...                ...
# 691             False                False         False              False
# 692             False                False         False              False
# 693             False                False         False              False
# 694             False                False         False              False
# 695             False                False         False              False
#
#      ACUSADO_SD  ACUSADO_TREN
# 0         False         False
# 1         False         False
# 2         False         False
# 3          True         False
# 4         False         False
# ..          ...           ...
# 691       False         False
# 692       False         False
# 693       False         False
# 694       False         False
# 695       False         False
#
# [694 rows x 30 columns]

# %%
corre_exp = hechos_corr.corr()
corre_exp
# Out:
#                          N_VICTIMAS       AÑO       MES  DIA_SEMANA      HORA  \
# N_VICTIMAS                 1.000000 -0.048160 -0.005072    0.092778 -0.090650
# AÑO                       -0.048160  1.000000 -0.042237   -0.016295 -0.046271
# MES                       -0.005072 -0.042237  1.000000   -0.064151  0.034835
# DIA_SEMANA                 0.092778 -0.016295 -0.064151    1.000000 -0.044164
# HORA                      -0.090650 -0.046271  0.034835   -0.044164  1.000000
# INTERSECCION              -0.016573 -0.076148 -0.025717    0.087640  0.010087
# COMUNA                     0.006645  0.002882  0.054147    0.016090 -0.040415
# TIPO_DE_CALLE_AUTOPISTA    0.000913  0.012816  0.034529   -0.021461 -0.005432
# TIPO_DE_CALLE_AVENIDA      0.000309  0.011556 -0.005950   -0.029255  0.028945
# TIPO_DE_CALLE_CALLE       -0.042280 -0.000565 -0.041485    0.006347  0.036660
# TIPO_DE_CALLE_GRAL PAZ     0.056013 -0.031318  0.031754    0.061621 -0.092641
# VICTIMA_AUTO               0.160503 -0.005668  0.007064    0.110921 -0.189086
# VICTIMA_BICICLETA         -0.035200  0.074367  0.073372   -0.019415  0.039899
# VICTIMA_CARGAS            -0.017015 -0.080315  0.049556    0.000934 -0.006571
# VICTIMA_MOTO              -0.031281  0.006269 -0.046782    0.010839 -0.103157
# VICTIMA_MOVIL              0.140676 -0.038206  0.004846    0.000498  0.007799
# VICTIMA_OBJETO FIJO        0.205205 -0.026996  0.024739    0.037890 -0.040617
# VICTIMA_PASAJEROS         -0.014359  0.010414  0.036359   -0.007630 -0.013854
# VICTIMA_PEATON            -0.082477  0.011734 -0.010134   -0.092468  0.225257
# VICTIMA_SD                -0.018203 -0.108868  0.017309    0.061026 -0.019104
# ACUSADO_AUTO              -0.003047  0.036349 -0.023470    0.134120 -0.034092
# ACUSADO_BICICLETA         -0.017015  0.031214  0.033373   -0.020441  0.009034
# ACUSADO_CARGAS            -0.008229  0.032810 -0.063564   -0.185624 -0.028060
# ACUSADO_MOTO              -0.021189 -0.034619  0.082915   -0.041312  0.126670
# ACUSADO_MULTIPLE          -0.026711  0.003844 -0.069399   -0.030773  0.019315
# ACUSADO_OBJETO FIJO        0.087911  0.123043 -0.056802    0.202584 -0.180582
# ACUSADO_OTRO              -0.015741  0.016972  0.025885   -0.006826 -0.007992
# ACUSADO_PASAJEROS         -0.004358 -0.094431  0.084654   -0.080246  0.109910
# ACUSADO_SD                -0.029776 -0.120531 -0.017114    0.063977 -0.053783
# ACUSADO_TREN              -0.006403  0.018204  0.035396   -0.018418  0.058363
#
#                          INTERSECCION    COMUNA  TIPO_DE_CALLE_AUTOPISTA  \
# N_VICTIMAS                  -0.016573  0.006645                 0.000913
# AÑO                         -0.076148  0.002882                 0.012816
# MES                         -0.025717  0.054147                 0.034529
# DIA_SEMANA                   0.087640  0.016090                -0.021461
# HORA                         0.010087 -0.040415                -0.005432
# INTERSECCION                 1.000000  0.031091                -0.255475
# COMUNA                       0.031091  1.000000                -0.032844
# TIPO_DE_CALLE_AUTOPISTA     -0.255475 -0.032844                 1.000000
# TIPO_DE_CALLE_AVENIDA        0.189809 -0.011280                -0.409013
# TIPO_DE_CALLE_CALLE         -0.102839 -0.113488                -0.157976
# TIPO_DE_CALLE_GRAL PAZ       0.078683  0.205837                -0.103339
# VICTIMA_AUTO                -0.008155  0.036488                 0.033930
# VICTIMA_BICICLETA           -0.066070 -0.062512                -0.067130
# VICTIMA_CARGAS              -0.043522 -0.007015                 0.066538
# VICTIMA_MOTO                -0.001106  0.066153                 0.133759
# VICTIMA_MOVIL                0.030502 -0.060827                -0.017282
# VICTIMA_OBJETO FIJO          0.021552  0.039562                -0.012211
# VICTIMA_PASAJEROS           -0.031059  0.069235                -0.027385
# VICTIMA_PEATON               0.057314 -0.080734                -0.139827
# VICTIMA_SD                  -0.064533  0.035280                 0.011616
# ACUSADO_AUTO                 0.019729  0.057786                -0.022869
# ACUSADO_BICICLETA           -0.077120  0.009477                -0.032449
# ACUSADO_CARGAS              -0.011916 -0.041415                 0.101025
# ACUSADO_MOTO                 0.010765  0.034257                -0.006099
# ACUSADO_MULTIPLE            -0.018682  0.041375                 0.013046
# ACUSADO_OBJETO FIJO         -0.128318  0.058127                 0.107382
# ACUSADO_OTRO                 0.052984  0.022499                -0.030020
# ACUSADO_PASAJEROS            0.070841 -0.125918                -0.139511
# ACUSADO_SD                   0.021829  0.051216                 0.029828
# ACUSADO_TREN                 0.021552  0.022185                -0.012211
#
#                          TIPO_DE_CALLE_AVENIDA  TIPO_DE_CALLE_CALLE  ...  \
# N_VICTIMAS                            0.000309            -0.042280  ...
# AÑO                                   0.011556            -0.000565  ...
# MES                                  -0.005950            -0.041485  ...
# DIA_SEMANA                           -0.029255             0.006347  ...
# HORA                                  0.028945             0.036660  ...
# INTERSECCION                          0.189809            -0.102839  ...
# COMUNA                               -0.011280            -0.113488  ...
# TIPO_DE_CALLE_AUTOPISTA              -0.409013            -0.157976  ...
# TIPO_DE_CALLE_AVENIDA                 1.000000            -0.625269  ...
# TIPO_DE_CALLE_CALLE                  -0.625269             1.000000  ...
# TIPO_DE_CALLE_GRAL PAZ               -0.409013            -0.157976  ...
# VICTIMA_AUTO                         -0.030225            -0.068942  ...
# VICTIMA_BICICLETA                     0.001089             0.097486  ...
# VICTIMA_CARGAS                       -0.069071            -0.013176  ...
# VICTIMA_MOTO                         -0.080128            -0.054378  ...
# VICTIMA_MOVIL                         0.042253            -0.026419  ...
# VICTIMA_OBJETO FIJO                  -0.048332            -0.018668  ...
# VICTIMA_PASAJEROS                     0.031885             0.001178  ...
# VICTIMA_PEATON                        0.127110             0.049829  ...
# VICTIMA_SD                           -0.081832             0.083339  ...
# ACUSADO_AUTO                         -0.020206             0.026504  ...
# ACUSADO_BICICLETA                    -0.039390             0.096114  ...
# ACUSADO_CARGAS                       -0.052762             0.005354  ...
# ACUSADO_MOTO                          0.051473            -0.040939  ...
# ACUSADO_MULTIPLE                     -0.009759            -0.030776  ...
# ACUSADO_OBJETO FIJO                  -0.055377            -0.064584  ...
# ACUSADO_OTRO                          0.009325            -0.006572  ...
# ACUSADO_PASAJEROS                     0.110100             0.036581  ...
# ACUSADO_SD                           -0.051617            -0.044308  ...
# ACUSADO_TREN                         -0.048332             0.077299  ...
#
#                          ACUSADO_AUTO  ACUSADO_BICICLETA  ACUSADO_CARGAS  \
# N_VICTIMAS                  -0.003047          -0.017015       -0.008229
# AÑO                          0.036349           0.031214        0.032810
# MES                         -0.023470           0.033373       -0.063564
# DIA_SEMANA                   0.134120          -0.020441       -0.185624
# HORA                        -0.034092           0.009034       -0.028060
# INTERSECCION                 0.019729          -0.077120       -0.011916
# COMUNA                       0.057786           0.009477       -0.041415
# TIPO_DE_CALLE_AUTOPISTA     -0.022869          -0.032449        0.101025
# TIPO_DE_CALLE_AVENIDA       -0.020206          -0.039390       -0.052762
# TIPO_DE_CALLE_CALLE          0.026504           0.096114        0.005354
# TIPO_DE_CALLE_GRAL PAZ       0.020554          -0.032449       -0.020317
# VICTIMA_AUTO                 0.064355          -0.037204       -0.037709
# VICTIMA_BICICLETA           -0.008290          -0.021079        0.068889
# VICTIMA_CARGAS              -0.033478          -0.010189        0.089420
# VICTIMA_MOTO                -0.023767          -0.028455        0.113991
# VICTIMA_MOVIL               -0.034688          -0.005427        0.038202
# VICTIMA_OBJETO FIJO          0.058873          -0.003834       -0.019607
# VICTIMA_PASAJEROS           -0.017567          -0.008599       -0.043971
# VICTIMA_PEATON              -0.003924           0.069420       -0.127720
# VICTIMA_SD                  -0.010418          -0.010901       -0.022621
# ACUSADO_AUTO                 1.000000          -0.065131       -0.333045
# ACUSADO_BICICLETA           -0.065131           1.000000       -0.052102
# ACUSADO_CARGAS              -0.333045          -0.052102        1.000000
# ACUSADO_MOTO                -0.193012          -0.030195       -0.154402
# ACUSADO_MULTIPLE            -0.102246          -0.015996       -0.081793
# ACUSADO_OBJETO FIJO         -0.202094          -0.031616       -0.161668
# ACUSADO_OTRO                -0.060256          -0.009427       -0.048202
# ACUSADO_PASAJEROS           -0.371810          -0.058167       -0.297434
# ACUSADO_SD                  -0.113978          -0.017831       -0.091178
# ACUSADO_TREN                -0.024510          -0.003834       -0.019607
#
#                          ACUSADO_MOTO  ACUSADO_MULTIPLE  ACUSADO_OBJETO FIJO  \
# N_VICTIMAS                  -0.021189         -0.026711             0.087911
# AÑO                         -0.034619          0.003844             0.123043
# MES                          0.082915         -0.069399            -0.056802
# DIA_SEMANA                  -0.041312         -0.030773             0.202584
# HORA                         0.126670          0.019315            -0.180582
# INTERSECCION                 0.010765         -0.018682            -0.128318
# COMUNA                       0.034257          0.041375             0.058127
# TIPO_DE_CALLE_AUTOPISTA     -0.006099          0.013046             0.107382
# TIPO_DE_CALLE_AVENIDA        0.051473         -0.009759            -0.055377
# TIPO_DE_CALLE_CALLE         -0.040939         -0.030776            -0.064584
# TIPO_DE_CALLE_GRAL PAZ      -0.024112          0.045040             0.072704
# VICTIMA_AUTO                -0.110252          0.027774             0.211498
# VICTIMA_BICICLETA           -0.062468          0.013492            -0.065407
# VICTIMA_CARGAS              -0.030195         -0.015996             0.018941
# VICTIMA_MOTO                 0.008184          0.014590             0.139443
# VICTIMA_MOVIL               -0.016082         -0.008519            -0.016838
# VICTIMA_OBJETO FIJO         -0.011363         -0.006020            -0.011898
# VICTIMA_PASAJEROS           -0.025483         -0.013499            -0.026682
# VICTIMA_PEATON               0.100715         -0.028164            -0.245417
# VICTIMA_SD                   0.016860         -0.017112            -0.033824
# ACUSADO_AUTO                -0.193012         -0.102246            -0.202094
# ACUSADO_BICICLETA           -0.030195         -0.015996            -0.031616
# ACUSADO_CARGAS              -0.154402         -0.081793            -0.161668
# ACUSADO_MOTO                 1.000000         -0.047402            -0.093693
# ACUSADO_MULTIPLE            -0.047402          1.000000            -0.049633
# ACUSADO_OBJETO FIJO         -0.093693         -0.049633             1.000000
# ACUSADO_OTRO                -0.027935         -0.014798            -0.029250
# ACUSADO_PASAJEROS           -0.172374         -0.091313            -0.180485
# ACUSADO_SD                  -0.052841         -0.027992            -0.055327
# ACUSADO_TREN                -0.011363         -0.006020            -0.011898
#
#                          ACUSADO_OTRO  ACUSADO_PASAJEROS  ACUSADO_SD  \
# N_VICTIMAS                  -0.015741          -0.004358   -0.029776
# AÑO                          0.016972          -0.094431   -0.120531
# MES                          0.025885           0.084654   -0.017114
# DIA_SEMANA                  -0.006826          -0.080246    0.063977
# HORA                        -0.007992           0.109910   -0.053783
# INTERSECCION                 0.052984           0.070841    0.021829
# COMUNA                       0.022499          -0.125918    0.051216
# TIPO_DE_CALLE_AUTOPISTA     -0.030020          -0.139511    0.029828
# TIPO_DE_CALLE_AVENIDA        0.009325           0.110100   -0.051617
# TIPO_DE_CALLE_CALLE         -0.006572           0.036581   -0.044308
# TIPO_DE_CALLE_GRAL PAZ       0.023400          -0.093782    0.116440
# VICTIMA_AUTO                 0.013546          -0.120000    0.038585
# VICTIMA_BICICLETA            0.058281           0.012832   -0.036888
# VICTIMA_CARGAS              -0.009427          -0.024833   -0.017831
# VICTIMA_MOTO                 0.045638          -0.185543    0.001250
# VICTIMA_MOVIL               -0.005020           0.031158   -0.009497
# VICTIMA_OBJETO FIJO         -0.003547          -0.021890   -0.006710
# VICTIMA_PASAJEROS           -0.007955           0.069064    0.084412
# VICTIMA_PEATON              -0.073173           0.268880   -0.086432
# VICTIMA_SD                  -0.010085          -0.062228    0.296131
# ACUSADO_AUTO                -0.060256          -0.371810   -0.113978
# ACUSADO_BICICLETA           -0.009427          -0.058167   -0.017831
# ACUSADO_CARGAS              -0.048202          -0.297434   -0.091178
# ACUSADO_MOTO                -0.027935          -0.172374   -0.052841
# ACUSADO_MULTIPLE            -0.014798          -0.091313   -0.027992
# ACUSADO_OBJETO FIJO         -0.029250          -0.180485   -0.055327
# ACUSADO_OTRO                 1.000000          -0.053813   -0.016496
# ACUSADO_PASAJEROS           -0.053813           1.000000   -0.101790
# ACUSADO_SD                  -0.016496          -0.101790    1.000000
# ACUSADO_TREN                -0.003547          -0.021890   -0.006710
#
#                          ACUSADO_TREN
# N_VICTIMAS                  -0.006403
# AÑO                          0.018204
# MES                          0.035396
# DIA_SEMANA                  -0.018418
# HORA                         0.058363
# INTERSECCION                 0.021552
# COMUNA                       0.022185
# TIPO_DE_CALLE_AUTOPISTA     -0.012211
# TIPO_DE_CALLE_AVENIDA       -0.048332
# TIPO_DE_CALLE_CALLE          0.077299
# TIPO_DE_CALLE_GRAL PAZ      -0.012211
# VICTIMA_AUTO                -0.014001
# VICTIMA_BICICLETA            0.181905
# VICTIMA_CARGAS              -0.003834
# VICTIMA_MOTO                -0.032663
# VICTIMA_MOVIL               -0.002042
# VICTIMA_OBJETO FIJO         -0.001443
# VICTIMA_PASAJEROS           -0.003236
# VICTIMA_PEATON              -0.029765
# VICTIMA_SD                  -0.004102
# ACUSADO_AUTO                -0.024510
# ACUSADO_BICICLETA           -0.003834
# ACUSADO_CARGAS              -0.019607
# ACUSADO_MOTO                -0.011363
# ACUSADO_MULTIPLE            -0.006020
# ACUSADO_OBJETO FIJO         -0.011898
# ACUSADO_OTRO                -0.003547
# ACUSADO_PASAJEROS           -0.021890
# ACUSADO_SD                  -0.006710
# ACUSADO_TREN                 1.000000
#
# [30 rows x 30 columns]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corre_exp,cmap='coolwarm',center=0)
plt.show()

# %% [markdown]
# ## Exportar archivos

# %%
hechos
# Out:
#             ID  N_VICTIMAS   AÑO  MES  DIA_SEMANA DIA_SEMANA_NOM       HORA  \
# 0    2016-0001           1  2016    1           4        VIERNES   4.000000
# 1    2016-0002           1  2016    1           5         SÁBADO   1.250000
# 2    2016-0003           1  2016    1           6        DOMINGO   7.000000
# 3    2016-0004           1  2016    1           6        DOMINGO   0.000000
# 4    2016-0005           1  2016    1           3         JUEVES   5.333333
# ..         ...         ...   ...  ...         ...            ...        ...
# 691  2021-0093           1  2021   12           0          LUNES  17.166667
# 692  2021-0094           1  2021   12           0          LUNES   1.166667
# 693  2021-0095           1  2021   12           3         JUEVES   0.716667
# 694  2021-0096           1  2021   12           2      MIÉRCOLES  10.500000
# 695  2021-0097           1  2021   11           3         JUEVES   6.166667
#
#     TIPO_DE_CALLE                                         VIAS_INVOL  \
# 0         AVENIDA  [PIEDRA BUENA AV., FERNANDEZ DE LA CRUZ, F., G...
# 1        GRAL PAZ              [PAZ, GRAL. AV., DE LOS CORRALES AV.]
# 2         AVENIDA                                   [ENTRE RIOS AV.]
# 3         AVENIDA         [LARRAZABAL AV., VILLEGAS, CONRADO, GRAL.]
# 4         AVENIDA            [SAN JUAN AV., SAENZ PE?A, LUIS, PRES.]
# ..            ...                                                ...
# 691       AVENIDA                                 [RIESTRA AV., MOM]
# 692     AUTOPISTA        [DELLEPIANE, LUIS, TTE. GRAL., LACARRA AV.]
# 693       AVENIDA                               [GAONA AV., TERRADA]
# 694       AVENIDA                                   [PERON, EVA AV.]
# 695         CALLE                              [PADRE CARLOS MUJICA]
#
#      INTERSECCION  COMUNA   PARTICIPANTES    VICTIMA    ACUSADO   LONGITUD  \
# 0               1       8       MOTO-AUTO       MOTO       AUTO -58.475340
# 1               1       9  AUTO-PASAJEROS       AUTO  PASAJEROS -58.508775
# 2               0       1       MOTO-AUTO       MOTO       AUTO -58.390403
# 3               1       8         MOTO-SD       MOTO         SD -58.465039
# 4               1       1  MOTO-PASAJEROS       MOTO  PASAJEROS -58.387183
# ..            ...     ...             ...        ...        ...        ...
# 691             1       7       MOTO-AUTO       MOTO       AUTO -58.433538
# 692             1       9       MOTO-AUTO       MOTO       AUTO -58.467398
# 693             1      11     MOTO-CARGAS       MOTO     CARGAS -58.472934
# 694             0       9     AUTO-CARGAS       AUTO     CARGAS -58.470668
# 695             0       1  BICICLETA-AUTO  BICICLETA       AUTO -58.379762
#
#        LATITUD
# 0   -34.687570
# 1   -34.669777
# 2   -34.631894
# 3   -34.680930
# 4   -34.622466
# ..         ...
# 691 -34.645616
# 692 -34.651178
# 693 -34.619847
# 694 -34.650217
# 695 -34.586796
#
# [694 rows x 16 columns]

# %%
hechos.to_csv('Archivos Finales/hechos.csv', index=False)

# %%
pd.DataFrame(frec_vias).reset_index().rename(columns={'index':'VIA','count':'N_SINIESTROS'}).to_csv('Archivos Finales/vias_invol.csv',index=False)
